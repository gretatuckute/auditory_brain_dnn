# %% [markdown]
# # Generate Figure 9 (regression)

# %%
from plot_utils_AUD import *
save = False
SAVEDIR = '../../compiled_plots/'
if not save:
    SAVEDIR = None

# %% [markdown]
# ## Neural dataset: NH2015 (trained models)

# %%
target = 'NH2015'
permuted_network = 'False'
sort_flag_manual = ['Kell2018word', 'Kell2018wordClean',
                 'ResNet50word', 'ResNet50wordClean']


barplot_across_models(source_models=sort_flag_manual,
                      target=target,
                      roi=None,
                      save=SAVEDIR,
                      randnetw=permuted_network,
                      aggregation='CV-splits-nit-10',
                      value_of_interest='median_r2_test_c',
                      sort_by=sort_flag_manual,
                      add_savestr=f'',
                      box_aspect=1)
# Out:
# /Users/gt/Documents/GitHub/auditory_brain_dnn/aud_dnn/analyze/plot_utils_AUD.py:2231: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Neural dataset: B2021 (trained models)

# %%
target = 'B2021'
permuted_network = 'False'
sort_flag_manual = ['Kell2018word', 'Kell2018wordClean',
                 'ResNet50word', 'ResNet50wordClean']


barplot_across_models(source_models=sort_flag_manual,
                      target=target,
                      roi=None,
                      save=SAVEDIR,
                      randnetw=permuted_network,
                      aggregation='CV-splits-nit-10',
                      value_of_interest='median_r2_test_c',
                      sort_by=sort_flag_manual,
                      add_savestr=f'',
                      box_aspect=1)
# Out:
# /Users/gt/Documents/GitHub/auditory_brain_dnn/aud_dnn/analyze/plot_utils_AUD.py:2231: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
