# %% [markdown]
# # Generate Figure 7

# %% [markdown]
# # Regression Figures

# %%
import sys
import os
sys.path.append(os.path.dirname(os.getcwd())) 
sys.path.append(os.path.dirname(os.path.dirname(os.getcwd())))
from plot_utils_AUD import *
save = False
SAVEDIR = '../../compiled_plots/'
if not save:
    SAVEDIR = None
    
source_models = FIG_7_MODEL_LIST
# Out:
# ROOT: /Users/gt/Documents/GitHub/auditory_brain_dnn

# %% [markdown]
# ## Neural dataset: NH2015 (trained models). Primary vs. Anterior ROI.

# %%
target = 'NH2015'
permuted_network = 'False' # Set to 'True' if we want to plot permuted models

# Select which non-primary ROI to plot
non_primary_roi = 'Anterior'

scatter_anat_roi_across_models(source_models=source_models,
                               target=target,
                               save=SAVEDIR,
                               randnetw=permuted_network,
                               condition_col='roi_label_general',
                               collapse_over_val_layer='median',
                               primary_rois=['Primary'], 
                               non_primary_rois=[non_primary_roi],
                               annotate=False,
                               save_str=f'',
                               value_of_interest='median_r2_test_c',
                               stats=False)
# Out:
# /Users/gt/Documents/GitHub/auditory_brain_dnn/aud_dnn/analyze/plot_utils_AUD.py:2048: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Neural dataset: NH2015 (trained models). Primary vs. Lateral ROI.

# %%
target = 'NH2015'
permuted_network = 'False'

# Select which non-primary ROI to plot
non_primary_roi = 'Lateral'

scatter_anat_roi_across_models(source_models=source_models,
                               target=target,
                               save=SAVEDIR,
                               randnetw=permuted_network,
                               condition_col='roi_label_general',
                               collapse_over_val_layer='median',
                               primary_rois=['Primary'], 
                               non_primary_rois=[non_primary_roi],
                               annotate=False,
                               save_str=f'',
                               value_of_interest='median_r2_test_c',
                               stats=False)

# %% [markdown]
# ## Neural dataset: NH2015 (trained models). Primary vs. Posterior ROI.

# %%
target = 'NH2015'
permuted_network = 'False'

# Select which non-primary ROI to plot
non_primary_roi = 'Posterior'

scatter_anat_roi_across_models(source_models=source_models,
                               target=target,
                               save=SAVEDIR,
                               randnetw=permuted_network,
                               condition_col='roi_label_general',
                               collapse_over_val_layer='median',
                               primary_rois=['Primary'], 
                               non_primary_rois=[non_primary_roi],
                               annotate=False,
                               save_str=f'',
                               value_of_interest='median_r2_test_c',
                               stats=False)

# %% [markdown]
# ## Neural dataset: B2021 (trained models). Primary vs. Anterior ROI.

# %%
target = 'B2021'
permuted_network = 'False'

# Select which non-primary ROI to plot
non_primary_roi = 'Anterior'

scatter_anat_roi_across_models(source_models=source_models,
                               target=target,
                               save=SAVEDIR,
                               randnetw=permuted_network,
                               condition_col='roi_label_general',
                               collapse_over_val_layer='median',
                               primary_rois=['Primary'], 
                               non_primary_rois=[non_primary_roi],
                               annotate=False,
                               save_str=f'',
                               value_of_interest='median_r2_test_c',
                               stats=False)

# %% [markdown]
# ## Neural dataset: B2021 (trained models). Primary vs. Lateral ROI.

# %%
target = 'B2021'
permuted_network = 'False'

# Select which non-primary ROI to plot
non_primary_roi = 'Lateral'

scatter_anat_roi_across_models(source_models=source_models,
                               target=target,
                               save=SAVEDIR,
                               randnetw=permuted_network,
                               condition_col='roi_label_general',
                               collapse_over_val_layer='median',
                               primary_rois=['Primary'], 
                               non_primary_rois=[non_primary_roi],
                               annotate=False,
                               save_str=f'',
                               value_of_interest='median_r2_test_c',
                               stats=False)

# %% [markdown]
# ## Neural dataset: B2021 (trained models). Primary vs. Posterior ROI.

# %%
target = 'B2021'
permuted_network = 'False'

# Select which non-primary ROI to plot
non_primary_roi = 'Posterior'

scatter_anat_roi_across_models(source_models=source_models,
                               target=target,
                               save=SAVEDIR,
                               randnetw=permuted_network,
                               condition_col='roi_label_general',
                               collapse_over_val_layer='median',
                               primary_rois=['Primary'], 
                               non_primary_rois=[non_primary_roi],
                               annotate=False,
                               save_str=f'',
                               value_of_interest='median_r2_test_c',
                               stats=False)

# %% [markdown]
# Note that the best layer per ROI values are aggregated using the function [barplot_best_layer_per_anat_ROI()](https://github.com/gretatuckute/auditory_brain_dnn/blob/main/aud_dnn/analyze/plot_utils_AUD.py#L3449) (an example call can be found [here](https://github.com/gretatuckute/auditory_brain_dnn/blob/main/aud_dnn/analyze/AUD_plot_main.py#L666)).

# %% [markdown]
# # RSA Figures

# %%
from rsa_matrix_calculation_all_models import *
from resources import FIG_7_MODEL_LIST

save = False
SAVEDIR = '../../compiled_plots/' # Or whichever directory you prefer
RESULTS_DIR = '../results'
if not save:
    SAVEDIR = None

# %%
make_best_layer_roi_scatter_plots(SAVEDIR,
                                  saved_rsa_best_layer_pckl=os.path.join(RESULTS_DIR, 'RSA', 'ALL_MODELS_best_layer_rsa_analysis_dict.pckl'),
                                  model_list=FIG_7_MODEL_LIST,
                                  extra_title='FIG7_BestLayerModels_')
# Out:
# FIG7_BestLayerModels_NH2015_Trained:  Avg across models best layer Primary: 0.37401175213675214, ROI: 0.4617855235042736
# FIG7_BestLayerModels_NH2015_Trained:  Wilcoxon signed-rank test between Primary and Anterior: 6.0, p-value: 0.00349
# Not running effect size because pingouin is not installed
# FIG7_BestLayerModels_NH2015_Trained:  Avg across models best layer Primary: 0.37401175213675214, ROI: 0.4939569978632479
# FIG7_BestLayerModels_NH2015_Trained:  Wilcoxon signed-rank test between Primary and Lateral: 2.0, p-value: 0.00236
# Not running effect size because pingouin is not installed
# FIG7_BestLayerModels_NH2015_Trained:  Avg across models best layer Primary: 0.37401175213675214, ROI: 0.535403311965812
# FIG7_BestLayerModels_NH2015_Trained:  Wilcoxon signed-rank test between Primary and Posterior: 0.0, p-value: 0.00065
# Not running effect size because pingouin is not installed
# ...
