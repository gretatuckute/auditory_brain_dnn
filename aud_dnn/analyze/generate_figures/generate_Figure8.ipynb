# %% [markdown]
# # Generate Figure 8

# %% [markdown]
# # Regression Figures

# %%
import sys
import os
sys.path.append(os.path.dirname(os.getcwd())) 
sys.path.append(os.path.dirname(os.path.dirname(os.getcwd())))
from plot_utils_AUD import *
save = False
SAVEDIR = '../../compiled_plots/'
if not save:
    SAVEDIR = None
# Out:
# ROOT: /Users/gt/Documents/GitHub/auditory_brain_dnn

# %% [markdown]
# ## Neural dataset: NH2015 (trained models)

# %%
target = 'NH2015'
permuted_network = 'False'
sort_flag_manual = FIG_8_MODEL_LIST

barplot_across_models(source_models=sort_flag_manual,
                      target=target,
                      roi=None,
                      save=SAVEDIR,
                      randnetw=permuted_network,
                      aggregation='CV-splits-nit-10',
                      value_of_interest='median_r2_test_c',
                      sort_by=sort_flag_manual,
                      add_savestr=f'',
                      box_aspect=0.8) # Note that hashing was added post-hoc
# Out:
# /Users/gt/Documents/GitHub/auditory_brain_dnn/aud_dnn/analyze/plot_utils_AUD.py:1727: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Neural dataset: B2021 (trained models)

# %%
target = 'B2021'
permuted_network = 'False'
sort_flag_manual = FIG_8_MODEL_LIST

barplot_across_models(source_models=sort_flag_manual,
                      target=target,
                      roi=None,
                      save=SAVEDIR,
                      randnetw=permuted_network,
                      aggregation='CV-splits-nit-10',
                      value_of_interest='median_r2_test_c',
                      sort_by=sort_flag_manual,
                      add_savestr=f'',
                      box_aspect=0.8) # Note that hashing was added post-hoc
# Out:
# /Users/gt/Documents/GitHub/auditory_brain_dnn/aud_dnn/analyze/plot_utils_AUD.py:1727: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# # RSA Figures

# %%
from rsa_matrix_calculation_all_models import *

save = False
SAVEDIR = '../../compiled_plots/' # Or whichever directory you prefer
RESULTS_DIR = '../results'
if not save:
    SAVEDIR = None

# %%
offset=0.35
make_all_voxel_rsa_bar_plots(save_fig_path=SAVEDIR,
                             saved_rsa_pckl_path=os.path.join(RESULTS_DIR, 'RSA', 'ALL_MODELS_all_dataset_rsa.pckl'),
                             model_list=FIG_8_MODEL_LIST + ['spectemp'],
                             model_order=FIG_8_MODEL_LIST,
                             extra_title='FIG8_Clean_Speech_',
                             bar_placement=np.array([0,
                                                     0.35,0.7+offset,
                                                     1.05+offset,1.4+2*offset,
                                                     1.75+2*offset,2.1+3*offset,
                                                     2.45+3*offset])
                             )
# Out:
# /Users/gt/Documents/GitHub/auditory_brain_dnn/aud_dnn/analyze/rsa_matrix_calculation_all_models.py:997: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
