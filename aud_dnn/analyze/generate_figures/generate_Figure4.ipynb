# %% [markdown]
# # Generate Figure 4

# %%
import sys
import os
sys.path.append(os.path.dirname(os.getcwd())) 
sys.path.append(os.path.dirname(os.path.dirname(os.getcwd())))
from plot_utils_AUD import *
save = False
SAVEDIR = '../../compiled_plots/' 
if not save:
    SAVEDIR = None
# Out:
# ROOT: /Users/gt/Documents/GitHub/auditory_brain_dnn

# %% [markdown]
# ## Components (CochResNet50Multitask, trained), scatter plots (Figure 4A)

# %%
target = 'NH2015comp'
permuted_network = 'False' 
source_model = 'ResNet50multitask'

scatter_NH2015comp_resp_vs_pred(source_model=source_model,
                                target=target,
                                randnetw=permuted_network,
                                save=SAVEDIR,
                                add_savestr=f'',
                                generate_scatter_plot=True,
                                obtain_partial_corr=False,)

# %% [markdown]
# ## Components (CochResNet50Multitask, permuted), scatter plots (Figure 4B)

# %%
target = 'NH2015comp'
permuted_network = 'True' 
source_model = 'ResNet50multitask'

scatter_NH2015comp_resp_vs_pred(source_model=source_model,
                                target=target,
                                randnetw=permuted_network,
                                save=SAVEDIR,
                                add_savestr=f'',
                                generate_scatter_plot=True,
                                obtain_partial_corr=False,)

# %% [markdown]
# ## Components (SpectroTemporal), scatter plots (Figure 4C)

# %%
import warnings
warnings.filterwarnings("ignore")
target = 'NH2015comp'
permuted_network = 'False' 
source_model = 'spectemp'

scatter_NH2015comp_resp_vs_pred(source_model=source_model,
                                target=target,
                                randnetw=permuted_network,
                                save=SAVEDIR,
                                add_savestr=f'',
                                generate_scatter_plot=True,
                                obtain_partial_corr=False,)
# Out:
# 1it [00:00, 307.41it/s]
# Loading df_output.pkl results from 1 folders
# Len of final df: 6
