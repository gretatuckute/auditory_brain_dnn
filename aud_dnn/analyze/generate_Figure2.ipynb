# %% [markdown]
# # Generate Figure 2

# %% [markdown]
# # Regression Figures

# %%
from plot_utils_AUD import *
save = False
SAVEDIR = '../../compiled_plots/' # Or whichever directory you prefer
if not save:
    SAVEDIR = None
# Out:
# ROOT: /mnt/home/jfeather/projects/fmri_testing/auditory_brain_dnn

# %% [markdown]
# ## Neural dataset: NH2015 (trained models)

# %%
target = 'NH2015'
permuted_network = 'False'
source_models = [model for model in FIG_2_5_MODEL_LIST if model != 'spectemp']

barplot_across_models(source_models=source_models,
                      target=target,
                      roi=None,
                      save=SAVEDIR,
                      randnetw=permuted_network,
                      aggregation='CV-splits-nit-10',
                      value_of_interest='median_r2_test_c',
                      sort_by='performance',
                      add_savestr=f'',
                      box_aspect=0.8)
# Out:
# /Users/gt/Documents/GitHub/auditory_brain_dnn/aud_dnn/analyze/plot_utils_AUD.py:1726: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Neural dataset: NH2015 (permuted models)

# %%
target = 'NH2015'
permuted_network = 'True'
source_models = [model for model in FIG_2_5_MODEL_LIST if model != 'spectemp']

barplot_across_models(source_models=source_models,
                      target=target,
                      roi=None,
                      save=SAVEDIR,
                      randnetw=permuted_network,
                      aggregation='CV-splits-nit-10',
                      value_of_interest='median_r2_test_c',
                      sort_by=NH2015_all_models_performance_order,
                      add_savestr=f'',
                      box_aspect=0.8)
# Out:
# /Users/gt/Documents/GitHub/auditory_brain_dnn/aud_dnn/analyze/plot_utils_AUD.py:1726: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Neural dataset: B2021 (trained models)

# %%
target = 'B2021'
permuted_network = 'False'
source_models = [model for model in FIG_2_5_MODEL_LIST if model != 'spectemp']

barplot_across_models(source_models=source_models,
                      target=target,
                      roi=None,
                      save=SAVEDIR,
                      randnetw=permuted_network,
                      aggregation='CV-splits-nit-10',
                      value_of_interest='median_r2_test_c',
                      sort_by='performance',
                      add_savestr=f'',
                      box_aspect=0.8)
# Out:
# /Users/gt/Documents/GitHub/auditory_brain_dnn/aud_dnn/analyze/plot_utils_AUD.py:1726: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Neural dataset: B2021 (permuted models)

# %%
target = 'B2021'
permuted_network = 'True'
source_models = [model for model in FIG_2_5_MODEL_LIST if model != 'spectemp']

barplot_across_models(source_models=source_models,
                      target=target,
                      roi=None,
                      save=SAVEDIR,
                      randnetw=permuted_network,
                      aggregation='CV-splits-nit-10',
                      value_of_interest='median_r2_test_c',
                      sort_by=B2021_all_models_performance_order,
                      add_savestr=f'',
                      box_aspect=0.8)
# Out:
# /Users/gt/Documents/GitHub/auditory_brain_dnn/aud_dnn/analyze/plot_utils_AUD.py:1726: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   df_grouped_w_spectemp['add_savestr'] = add_savestr

# %% [markdown]
# Note that the best layer (selected using independent data from the cross-validation splits) are used in these plots. The layer selection procedure can be performed using the [select_r2_test_CV_splits_nit()](https://github.com/gretatuckute/auditory_brain_dnn/blob/main/aud_dnn/analyze/plot_utils_AUD.py#L247) function (an example call can be found [here](https://github.com/gretatuckute/auditory_brain_dnn/blob/main/aud_dnn/analyze/AUD_plot_main.py#L634)).

# %% [markdown]
# ## Scatters with model evaluation consistency across seeds for in-house models

# %%
target = 'NH2015' # 'NH2015' or 'B2021'
SEED1_source_models = ['Kell2018word', 'Kell2018speaker',  'Kell2018audioset', 'Kell2018multitask',
                       'ResNet50word', 'ResNet50speaker', 'ResNet50audioset', 'ResNet50multitask',]
SEED2_source_models = ['Kell2018wordSeed2', 'Kell2018speakerSeed2', 'Kell2018audiosetSeed2', 'Kell2018multitaskSeed2',
                       'ResNet50wordSeed2', 'ResNet50speakerSeed2', 'ResNet50audiosetSeed2',  'ResNet50multitaskSeed2',]
permuted_network = 'False' # 'False' or 'True'
ylim = [0.6, 0.8]
add_savestr = f'_seed1-vs-seed2'

scatter_across_models(source_models=SEED1_source_models + SEED2_source_models,
                     models1=SEED1_source_models,
                     models2=SEED2_source_models,
                     target=target,
                     save=SAVEDIR,
                      randnetw=permuted_network,
                      aggregation='CV-splits-nit-10',
                      value_of_interest='median_r2_test_c',
                     add_savestr=add_savestr,
                     ylim=ylim,
                     xlim=ylim)
# Out:
# /Users/gt/Documents/GitHub/auditory_brain_dnn/aud_dnn/analyze/plot_utils_AUD.py:1894: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   df_grouped['r2'] = r2

# %% [markdown]
# # RSA Figures

# %%
from rsa_matrix_calculation_all_models import *

save = False
SAVEDIR = '../../compiled_plots/' # Or whichever directory you prefer
RESULTS_DIR = '../results'
if not save:
    SAVEDIR = None
# Out:
# ['/mnt/home/jfeather/miniconda3/envs/auditory_brain_dnn/lib/python36.zip', '/mnt/home/jfeather/miniconda3/envs/auditory_brain_dnn/lib/python3.6', '/mnt/home/jfeather/miniconda3/envs/auditory_brain_dnn/lib/python3.6/lib-dynload', '', '/mnt/home/jfeather/miniconda3/envs/auditory_brain_dnn/lib/python3.6/site-packages', '/mnt/home/jfeather/miniconda3/envs/auditory_brain_dnn/lib/python3.6/site-packages/IPython/extensions', '/mnt/home/jfeather/.ipython', '/mnt/home/jfeather/projects/fmri_testing/auditory_brain_dnn/aud_dnn', '../.']

# %% [markdown]
# ## Figure 2 RSA bar plots for NH2015 and B2021, trained and untrained networks

# %%
# Figure 2 bar plot, 19 models in main analysis
make_all_voxel_rsa_bar_plots_from_p
ckl(os.path.join(RESULTS_DIR, 'RSA', 'ALL_MODELS_all_dataset_rsa.pckl'), 
                                       save_fig_path = SAVEDIR,
                                       model_list=FIG_2_5_MODEL_LIST,
                                       model_order=None,
                                       )

# %% [markdown]
# ## Scatters with model evaluation consistency across seeds for in-house models

# %%
FIG2_SEED_PAIRS = [['Kell2018word', 'Kell2018wordSeed2'],
                   ['Kell2018speaker', 'Kell2018speakerSeed2'],
                   ['Kell2018audioset', 'Kell2018audiosetSeed2'],
                   ['Kell2018multitask', 'Kell2018multitaskSeed2'],
                   ['ResNet50word', 'ResNet50wordSeed2'],
                   ['ResNet50speaker', 'ResNet50speakerSeed2'],
                   ['ResNet50audioset', 'ResNet50audiosetSeed2'],
                   ['ResNet50multitask', 'ResNet50multitaskSeed2']
                   ]

make_model_vs_model_scatter(SAVEDIR,
                            model_pairs=FIG2_SEED_PAIRS,
                            saved_rsa_pckl_path=os.path.join(RESULTS_DIR, 'RSA', 'ALL_MODELS_all_dataset_rsa.pckl'),
                            extra_title='FIG2_Seed_Scatter_',
                           )
# Out:
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
