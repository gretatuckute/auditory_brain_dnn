# %% [markdown]
# # Generate Figure 2 (regression)

# %%
from plot_utils_AUD import *
save = False
SAVEDIR = '../../compiled_plots/'
if not save:
    SAVEDIR = None

# %% [markdown]
# ## Neural dataset: NH2015 (trained models)

# %%
target = 'NH2015'
permuted_network = 'False'
source_models = [ 'Kell2018word', 'Kell2018speaker',  'Kell2018music', 'Kell2018audioset', 'Kell2018multitask',
                 'ResNet50word', 'ResNet50speaker', 'ResNet50music', 'ResNet50audioset',   'ResNet50multitask',
                 'AST',  'wav2vec', 'DCASE2020', 'DS2',  'VGGish', 'ZeroSpeech2020', 'S2T', 'metricGAN', 'sepformer']

barplot_across_models(source_models=source_models,
                      target=target,
                      roi=None,
                      save=SAVEDIR,
                      randnetw=permuted_network,
                      aggregation='CV-splits-nit-10',
                      value_of_interest='median_r2_test_c',
                      sort_by='performance',
                      add_savestr=f'',
                      box_aspect=0.8)
# Out:
# /Users/gt/Documents/GitHub/auditory_brain_dnn/aud_dnn/analyze/plot_utils_AUD.py:2234: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Neural dataset: B2021 (trained models)

# %%
target = 'B2021'
permuted_network = 'False'
source_models = [ 'Kell2018word', 'Kell2018speaker',  'Kell2018music', 'Kell2018audioset', 'Kell2018multitask',
                 'ResNet50word', 'ResNet50speaker', 'ResNet50music', 'ResNet50audioset',   'ResNet50multitask',
                 'AST',  'wav2vec', 'DCASE2020', 'DS2',  'VGGish', 'ZeroSpeech2020', 'S2T', 'metricGAN', 'sepformer']

barplot_across_models(source_models=source_models,
                      target=target,
                      roi=None,
                      save=SAVEDIR,
                      randnetw=permuted_network,
                      aggregation='CV-splits-nit-10',
                      value_of_interest='median_r2_test_c',
                      sort_by='performance',
                      add_savestr=f'',
                      box_aspect=0.8)
# Out:
# /Users/gt/Documents/GitHub/auditory_brain_dnn/aud_dnn/analyze/plot_utils_AUD.py:2234: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Scatters with model evaluation consistency across seeds for in-house models
